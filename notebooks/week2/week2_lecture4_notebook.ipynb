# %% [markdown]
# ### Programming for Biomedical Informatics
# #### Week 2 - FTP Bulk Download & APIs
#
# This week we're going to practice using bulk download and API in a practical example. This week we are going to be looking at a resource called GenCC - The Gene Curation Collection - https://thegencc.org
#
# GenCC is primarily focussed on providing a unified source of gene-disease relationships that is harmonised across the various international efforts that operate in this space. In the process of doing so they are establishing standards for curation and annotation to maximise the consitency and useability of their data.
#
# Our efforts today will focus on a full FTP download of the GenCC data, some parsing, and use of the API at Bioportal to gather more information about some of the elements of the GenCC data. This is a **slightly** contrived example, but hopefully it is both interesting and useful to give you an idea of how these two approaches can be used together.

# %%
import pandas as pd
import urllib.request
from prettytable import PrettyTable

# %%
# Step One - Bulk Download of GenCC data

'''The url to the latest version of the data is here - https://search.thegencc.org/download/action/submissions-export-tsv'''

#pseudocode 1 - download the data using the urllib library
data = urllib.request.urlopen('https://search.thegencc.org/download/action/submissions-export-tsv')

#pseudocode 2 - read the data into a pandas dataframe *you can see from the url that the data is tab separated*
data = pd.read_csv(data, sep='\t')

#pseudocode 3 - look ay the first few rows of the dataframe
print(data.head())
# Out:
#                                                 uuid  gene_curie gene_symbol  \
# 0  GENCC_000101-HGNC_10896-OMIM_182212-HP_0000006...  HGNC:10896         SKI
# 1  GENCC_000101-HGNC_16636-OMIM_171300-HP_0000006...  HGNC:16636       KIF1B
# 2  GENCC_000101-HGNC_16636-OMIM_118210-HP_0000006...  HGNC:16636       KIF1B
# 3  GENCC_000101-HGNC_17939-OMIM_617532-HP_0000007...  HGNC:17939     SLC45A1
# 4  GENCC_000101-HGNC_11071-OMIM_616291-HP_0000007...  HGNC:11071      SLC9A1
#
#    disease_curie                                      disease_title  \
# 0  MONDO:0008426                       Shprintzen-Goldberg syndrome
# 1  MONDO:0008233                                   pheochromocytoma
# 2  MONDO:0007308               Charcot-Marie-Tooth disease type 2A1
# 3  MONDO:0044322  intellectual developmental disorder with neuro...
# 4  MONDO:0014572                        Lichtenstein-Knorr syndrome
#
#   disease_original_curie disease_original_title classification_curie  \
# 0            OMIM:182212            OMIM:182212         GENCC:100001
# 1            OMIM:171300            OMIM:171300         GENCC:100003
# 2            OMIM:118210            OMIM:118210         GENCC:100004
# 3            OMIM:617532            OMIM:617532         GENCC:100004
# 4            OMIM:616291            OMIM:616291         GENCC:100004
#
#   classification_title   moi_curie  ... submitted_as_submitter_name  \
# 0           Definitive  HP:0000006  ...              Ambry Genetics
# 1             Moderate  HP:0000006  ...              Ambry Genetics
# 2              Limited  HP:0000006  ...              Ambry Genetics
# 3              Limited  HP:0000007  ...              Ambry Genetics
# 4              Limited  HP:0000007  ...              Ambry Genetics
#
#   submitted_as_classification_id submitted_as_classification_name  \
# 0                   GENCC:100001                       Definitive
# 1                   GENCC:100003                         Moderate
# 2                   GENCC:100004                          Limited
# 3                   GENCC:100004                          Limited
# 4                   GENCC:100004                          Limited
#
#      submitted_as_date submitted_as_public_report_url submitted_as_notes  \
# 0  2018-03-30 13:31:56                            NaN                NaN
# 1  2019-12-04 13:30:43                            NaN                NaN
# 2  2022-09-02 00:00:00                            NaN                NaN
# 3  2020-06-26 13:32:00                            NaN                NaN
# 4  2018-08-31 13:32:02                            NaN                NaN
#
#   submitted_as_pmids                submitted_as_assertion_criteria_url  \
# 0                NaN                                     PMID: 28106320
# 1                NaN                                     PMID: 28106320
# 2                NaN  https://onlinelibrary.wiley.com/doi/10.1002/hu...
# 3                NaN                                     PMID: 28106320
# 4                NaN                                     PMID: 28106320
#
#   submitted_as_submission_id submitted_run_date
# 0                       1034         2020-12-24
# 1                      69237         2020-12-24
# 2                      61327         2023-08-19
# 3                      72178         2020-12-24
# 4                       1705         2020-12-24
#
# [5 rows x 30 columns]

# %%
# Step Two - Gene Counts by Disease

'''Now we want a summary of how many genes have been annotated to each disease.'''

#pseudocode 4 - group the data by disease and count the number of genes for each disease (think of the pandas function that does this)
data = data.groupby('disease_title').count()

#pseudocode 5 - sort the data in descending order
data = data.sort_values('uuid', ascending=False)

#pseudocode 6 - look at the first few rows of the dataframe
print(data.head())

'''There's a nice package called PrettyTable that can be used to print the data in a nice table format. You can install it using 'conda install prettytable'''

#make some simple two-column data
data2 = [['disease1', 1000], ['disease2', 2000], ['disease3', 3000], ['disease4', 4000], ['disease5', 5000]]

# create a table
table = PrettyTable()

# add the columns
table.field_names = ['Disease Name','Number of Genes']

# add the rows
for row in data2:
    table.add_row(row)

# print the table
print(table)

# pseudocode 7 - create a table using the PrettyTable package
gene_counts_table = PrettyTable()
gene_counts_table.field_names = ['Disease Name','Number of Genes']
for index, row in data.iterrows():
    gene_counts_table.add_row([index, row['uuid']])
print(gene_counts_table)

'''There is a very nice plotting package called seaborn that can be used to create plots. You can install it using 'conda install seaborn.
Here's an example of how to create a horizontal bar chart using seaborn'''

#plot a horizontal bar chart of the data
import seaborn as sns
import pandas as pd

# set the style
sns.set_style('darkgrid')

# plot the data
sns.barplot(x='Number of Genes', y='Disease Name', data=pd.DataFrame(data, columns=['Disease Name', 'Number of Genes']))

#pseudocode 8 - plot the 10 diseases with the most genes
sns.barplot(x='Number of Genes', y='Disease Name', data=pd.DataFrame(data.head(10), columns=['Disease Name', 'Number of Genes']))
# Out:
#                                                     uuid  gene_curie  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                     1           1
# lethal fetal cerebrorenogenitourinary agenesis/...     1           1
# leukodystrophy, hypomyelinating, 26, with chond...     1           1
# leukodystrophy, hypomyelinating, 25                    1           1
# leukodystrophy, hypomyelinating, 24                    1           1
#
#                                                     gene_symbol  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                            1
# lethal fetal cerebrorenogenitourinary agenesis/...            1
# leukodystrophy, hypomyelinating, 26, with chond...            1
# leukodystrophy, hypomyelinating, 25                           1
# leukodystrophy, hypomyelinating, 24                           1
#
#                                                     disease_curie  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                              1
# lethal fetal cerebrorenogenitourinary agenesis/...              1
# leukodystrophy, hypomyelinating, 26, with chond...              1
# leukodystrophy, hypomyelinating, 25                             1
# leukodystrophy, hypomyelinating, 24                             1
#
#                                                     disease_original_curie  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                       1
# lethal fetal cerebrorenogenitourinary agenesis/...                       1
# leukodystrophy, hypomyelinating, 26, with chond...                       1
# leukodystrophy, hypomyelinating, 25                                      1
# leukodystrophy, hypomyelinating, 24                                      1
#
#                                                     disease_original_title  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                       1
# lethal fetal cerebrorenogenitourinary agenesis/...                       1
# leukodystrophy, hypomyelinating, 26, with chond...                       1
# leukodystrophy, hypomyelinating, 25                                      1
# leukodystrophy, hypomyelinating, 24                                      1
#
#                                                     classification_curie  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                     1
# lethal fetal cerebrorenogenitourinary agenesis/...                     1
# leukodystrophy, hypomyelinating, 26, with chond...                     1
# leukodystrophy, hypomyelinating, 25                                    1
# leukodystrophy, hypomyelinating, 24                                    1
#
#                                                     classification_title  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                     1
# lethal fetal cerebrorenogenitourinary agenesis/...                     1
# leukodystrophy, hypomyelinating, 26, with chond...                     1
# leukodystrophy, hypomyelinating, 25                                    1
# leukodystrophy, hypomyelinating, 24                                    1
#
#                                                     moi_curie  moi_title  ...  \
# disease_title                                                             ...
# 2-aminoadipic 2-oxoadipic aciduria                          1          1  ...
# lethal fetal cerebrorenogenitourinary agenesis/...          1          1  ...
# leukodystrophy, hypomyelinating, 26, with chond...          1          1  ...
# leukodystrophy, hypomyelinating, 25                         1          1  ...
# leukodystrophy, hypomyelinating, 24                         1          1  ...
#
#                                                     submitted_as_submitter_name  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                            1
# lethal fetal cerebrorenogenitourinary agenesis/...                            1
# leukodystrophy, hypomyelinating, 26, with chond...                            1
# leukodystrophy, hypomyelinating, 25                                           1
# leukodystrophy, hypomyelinating, 24                                           1
#
#                                                     submitted_as_classification_id  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                               1
# lethal fetal cerebrorenogenitourinary agenesis/...                               1
# leukodystrophy, hypomyelinating, 26, with chond...                               1
# leukodystrophy, hypomyelinating, 25                                              1
# leukodystrophy, hypomyelinating, 24                                              1
#
#                                                     submitted_as_classification_name  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                                 1
# lethal fetal cerebrorenogenitourinary agenesis/...                                 1
# leukodystrophy, hypomyelinating, 26, with chond...                                 1
# leukodystrophy, hypomyelinating, 25                                                1
# leukodystrophy, hypomyelinating, 24                                                1
#
#                                                     submitted_as_date  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                  1
# lethal fetal cerebrorenogenitourinary agenesis/...                  1
# leukodystrophy, hypomyelinating, 26, with chond...                  1
# leukodystrophy, hypomyelinating, 25                                 1
# leukodystrophy, hypomyelinating, 24                                 1
#
#                                                     submitted_as_public_report_url  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                               1
# lethal fetal cerebrorenogenitourinary agenesis/...                               1
# leukodystrophy, hypomyelinating, 26, with chond...                               1
# leukodystrophy, hypomyelinating, 25                                              1
# leukodystrophy, hypomyelinating, 24                                              1
#
#                                                     submitted_as_notes  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                   1
# lethal fetal cerebrorenogenitourinary agenesis/...                   1
# leukodystrophy, hypomyelinating, 26, with chond...                   1
# leukodystrophy, hypomyelinating, 25                                  1
# leukodystrophy, hypomyelinating, 24                                  1
#
#                                                     submitted_as_pmids  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                   1
# lethal fetal cerebrorenogenitourinary agenesis/...                   1
# leukodystrophy, hypomyelinating, 26, with chond...                   1
# leukodystrophy, hypomyelinating, 25                                  1
# leukodystrophy, hypomyelinating, 24                                  1
#
#                                                     submitted_as_assertion_criteria_url  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                                    1
# lethal fetal cerebrorenogenitourinary agenesis/...                                    1
# leukodystrophy, hypomyelinating, 26, with chond...                                    1
# leukodystrophy, hypomyelinating, 25                                                   1
# leukodystrophy, hypomyelinating, 24                                                   1
#
#                                                     submitted_as_submission_id  \
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                           1
# lethal fetal cerebrorenogenitourinary agenesis/...                           1
# leukodystrophy, hypomyelinating, 26, with chond...                           1
# leukodystrophy, hypomyelinating, 25                                          1
# leukodystrophy, hypomyelinating, 24                                          1
#
#                                                     submitted_run_date
# disease_title
# 2-aminoadipic 2-oxoadipic aciduria                                   1
# lethal fetal cerebrorenogenitourinary agenesis/...                   1
# leukodystrophy, hypomyelinating, 26, with chond...                   1
# leukodystrophy, hypomyelinating, 25                                  1
# leukodystrophy, hypomyelinating, 24                                  1
#
# [5 rows x 29 columns]
# +--------------+-----------------+
# | Disease Name | Number of Genes |
# +--------------+-----------------+
# |   disease1   |       1000      |
# |   disease2   |       2000      |
# |   disease3   |       3000      |
# |   disease4   |       4000      |
# |   disease5   |       5000      |
# +--------------+-----------------+
# +--------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# |                                                                   Disease Name                                                                   | Number of Genes |
# +--------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# |                                                        2-aminoadipic 2-oxoadipic aciduria                                                        |        1        |
# |                                        lethal fetal cerebrorenogenitourinary agenesis/hypoplasia syndrome                                        |        1        |
# |                                            leukodystrophy, hypomyelinating, 26, with chondrodysplasia                                            |        1        |
# |                                                       leukodystrophy, hypomyelinating, 25                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 24                                                        |        1        |
# |                    leukodystrophy, hypomyelinating, 23, with ataxia, deafness, liver dysfunction, and dilated cardiomyopathy                     |        1        |
# |                                                       leukodystrophy, hypomyelinating, 22                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 21                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 20                                                        |        1        |
# |                                             leukodystrophy, hypomyelinating, 19, transient infantile                                             |        1        |
# |                                                       leukodystrophy, hypomyelinating, 18                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 17                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 16                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 15                                                        |        1        |
# |                                                       leukodystrophy, hypomyelinating, 14                                                        |        1        |
# |                                        leukodystrophy and acquired microcephaly with or without dystonia;                                        |        1        |
# |                                                                  leukodystrophy                                                                  |        1        |
# |                                                      leukocyte adhesion deficiency type II                                                       |        1        |
# |                                                         leukocyte adhesion deficiency 3                                                          |        1        |
# |                                                         leukocyte adhesion deficiency 1                                                          |        1        |
# |                                                leukemia, acute lymphocytic, susceptibility to, 1                                                 |        1        |
# |                                               leukemia, acute lymphoblastic, susceptibility to, 3                                                |        1        |
# |                                                          lethal restrictive dermopathy                                                           |        1        |
# |                                                  lethal polymalformative syndrome, Boissel type                                                  |        1        |
# |                                                       lethal osteosclerotic bone dysplasia                                                       |        1        |
# |                                            lethal occipital encephalocele-skeletal dysplasia syndrome                                            |        1        |
# |                                                        lethal multiple pterygium syndrome                                                        |        1        |
# |                              leukoencephalopathy with brain stem and spinal cord involvement-high lactate syndrome                               |        1        |
# |                                                leukoencephalopathy with calcifications and cysts                                                 |        1        |
# |                                      leukoencephalopathy with mild cerebellar ataxia and white matter edema                                      |        1        |
# |                                              linear skin defects with multiple congenital anomalies                                              |        1        |
# |                                                                 lissencephaly 10                                                                 |        1        |
# |                                                         lipoyl transferase 1 deficiency                                                          |        1        |
# |                                                            lipoprotein glomerulopathy                                                            |        1        |
# |                                                                lipoid proteinosis                                                                |        1        |
# |                                                        lipoic acid synthetase deficiency                                                         |        1        |
# |                                               lipodystrophy, partial, acquired, susceptibility to                                                |        1        |
# |                                                                  lipodystrophy                                                                   |        1        |
# |                                                           lipase deficiency, combined                                                            |        1        |
# |                                             linear skin defects with multiple congenital anomalies 3                                             |        1        |
# |                                             linear skin defects with multiple congenital anomalies 2                                             |        1        |
# |                                             linear skin defects with multiple congenital anomalies 1                                             |        1        |
# |                                                         linear nevus sebaceous syndrome                                                          |        1        |
# |                                                 leukoencephalopathy with vanishing white matter                                                  |        1        |
# |                                                              limb-mammary syndrome                                                               |        1        |
# |                                              limb-girdle muscular dystrophy due to POMK deficiency                                               |        1        |
# |                                    leukoencephalopathy-thalamus and brainstem anomalies-high lactate syndrome                                    |        1        |
# |                                          leukoencephalopathy-ataxia-hypodontia-hypomyelination syndrome                                          |        1        |
# |                                              leukoencephalopathy, progressive, with ovarian failure                                              |        1        |
# |                                   leukoencephalopathy, progressive, infantile-onset, with or without deafness                                    |        1        |
# |                                      leukoencephalopathy, motor delay, spasticity, and dysarthria syndrome                                       |        1        |
# |                                            leukoencephalopathy, diffuse hereditary, with spheroids 1                                             |        1        |
# |                              leukoencephalopathy, developmental delay, and episodic neurologic regression syndrome                               |        1        |
# |                                leukoencephalopathy, acute reversible, with increased urinary alpha-ketoglutarate                                 |        1        |
# |                                                leukoencephalopathy with vanishing white matter 1                                                 |        1        |
# |                         lethal left ventricular non-compaction-seizures-hypotonia-cataract-developmental delay syndrome                          |        1        |
# |                                               lethal congenital glycogen storage disease of heart                                                |        1        |
# |                                        juvenile polyposis/hereditary hemorrhagic telangiectasia syndrome                                         |        1        |
# |                                                     lethal congenital contracture syndrome 9                                                     |        1        |
# |                                                           late-onset Parkinson disease                                                           |        1        |
# |                                                      late-adult onset retinitis pigmentosa                                                       |        1        |
# |                                                        laryngo-onycho-cutaneous syndrome                                                         |        1        |
# |               language delay and attention deficit-hyperactivity disorder/cognitive impairment with or without cardiac arrhythmia                |        1        |
# |                                                               lamellar ichthyosis                                                                |        1        |
# |                                                      lacrimoauriculodentodigital syndrome 3                                                      |        1        |
# |                                          kyphosis-lateral tongue atrophy-myofibrillar myopathy syndrome                                          |        1        |
# |                                   kyphoscoliosis-lateral tongue atrophy-hereditary spastic paraplegia syndrome                                   |        1        |
# |                                                                 kidney disorder                                                                  |        1        |
# |                                                                kidney Wilms tumor                                                                |        1        |
# |                                           ketoacidosis due to monocarboxylate transporter-1 deficiency                                           |        1        |
# |                                                          keratosis pilaris atrophicans                                                           |        1        |
# |                                                        keratosis palmoplantaris striata 2                                                        |        1        |
# |                                     keratosis linearis-ichthyosis congenita-sclerosing keratoderma syndrome                                      |        1        |
# |                                               keratosis follicularis spinulosa decalvans, X-linked                                               |        1        |
# |                                                    keratosis follicularis spinulosa decalvans                                                    |        1        |
# |                                                           keratolytic winter erythema                                                            |        1        |
# |                                                        keratoderma hereditarium mutilans                                                         |        1        |
# |                                                                  keratoconus 9                                                                   |        1        |
# |                                                                  keratoconus 1                                                                   |        1        |
# |                                                                   keratoconus                                                                    |        1        |
# |                                                           keratitis fugax hereditaria                                                            |        1        |
# |                                                       karyomegalic interstitial nephritis                                                        |        1        |
# |                                juvenile-onset diabetes mellitus-central and peripheral neurodegeneration syndrome                                |        1        |
# |                                                            juvenile sialidosis type 2                                                            |        1        |
# |                                                   late-onset junctional epidermolysis bullosa                                                    |        1        |
# |                                                           late-onset nephronophthisis                                                            |        1        |
# |                                                         late-onset retinal degeneration                                                          |        1        |
# |                                                             lessel-kubisch syndrome                                                              |        1        |
# |                                                     lethal congenital contracture syndrome 8                                                     |        1        |
# |                                                     lethal congenital contracture syndrome 7                                                     |        1        |
# |                                                     lethal congenital contracture syndrome 6                                                     |        1        |
# |                                                     lethal congenital contracture syndrome 4                                                     |        1        |
# |                                                     lethal congenital contracture syndrome 3                                                     |        1        |
# |                                                     lethal congenital contracture syndrome 2                                                     |        1        |
# |                                                    lethal congenital contracture syndrome 11                                                     |        1        |
# |                                                     lethal congenital contracture syndrome 1                                                     |        1        |
# |                                            lethal arthrogryposis-anterior horn cell disease syndrome                                             |        1        |
# |                                             lethal arteriopathy syndrome due to fibulin-4 deficiency                                             |        1        |
# |                                                    lethal acantholytic epidermolysis bullosa                                                     |        1        |
# |                                                                  leiomyosarcoma                                                                  |        1        |
# |                                                           lateral meningocele syndrome                                                           |        1        |
# |                                                         left ventricular noncompaction 8                                                         |        1        |
# |                                                         left ventricular noncompaction 7                                                         |        1        |
# |                                                        left ventricular noncompaction 10                                                         |        1        |
# |                                                         left ventricular noncompaction 1                                                         |        1        |
# |                                                          left ventricular noncompaction                                                          |        1        |
# |                                                          leber congenital amaurosis 19                                                           |        1        |
# |                                                             laurin-Sandrow syndrome                                                              |        1        |
# |                                                         lattice corneal dystrophy type I                                                         |        1        |
# |                                                                 lathosterolosis                                                                  |        1        |
# |                                                      laterality defects, autosomal dominant                                                      |        1        |
# |                                                                lateral sclerosis                                                                 |        1        |
# |                                                                 lissencephaly 4                                                                  |        1        |
# |                                                        lissencephaly 6 with microcephaly                                                         |        1        |
# |                                                    lissencephaly 7 with cerebellar hypoplasia                                                    |        1        |
# |                                                                 lissencephaly 8                                                                  |        1        |
# |                                                          malignant pancreatic neoplasm                                                           |        1        |
# |                                                 malignant migrating partial seizures of infancy                                                  |        1        |
# |                                                   malignant hyperthermia, susceptibility to, 5                                                   |        1        |
# |                                                   malignant hyperthermia, susceptibility to, 1                                                   |        1        |
# |                                                       malignant hyperthermia of anesthesia                                                       |        1        |
# |                                                     maleylacetoacetate isomerase deficiency                                                      |        1        |
# |                                 male infertility with azoospermia or oligozoospermia due to single gene mutation                                 |        1        |
# |                                                     male infertility due to globozoospermia                                                      |        1        |
# |                                                                 male infertility                                                                 |        1        |
# |                                                                  mal de Meleda                                                                   |        1        |
# |                                                          macular dystrophy, retinal, 4                                                           |        1        |
# |                                                 macular dystrophy with central cone involvement                                                  |        1        |
# |                                                        macular degeneration, early-onset                                                         |        1        |
# |                                                       macular degeneration, age-related, 3                                                       |        1        |
# |                                                     macular degeneration, X-linked atrophic                                                      |        1        |
# |                                                            macular corneal dystrophy                                                             |        1        |
# |                          macrothrombocytopenia-lymphedema-developmental delay-facial dysmorphism-camptodactyly syndrome                          |        1        |
# |                                              macrothrombocytopenia, isolated, 1, autosomal dominant                                              |        1        |
# |                                                         macrothrombocytopenia, isolated                                                          |        1        |
# |                     macrothrombocytopenia and granulocyte inclusions with or without nephritis or sensorineural hearing loss                     |        1        |
# |                                            macrocephaly/megalencephaly syndrome, autosomal recessive                                             |        1        |
# |                              macrocephaly-intellectual disability-neurodevelopmental disorder-small thorax syndrome                              |        1        |
# |                                                    macrocephaly-developmental delay syndrome                                                     |        1        |
# |                                                           macrocephaly-autism syndrome                                                           |        1        |
# |                          macrocephaly, neurodevelopmental delay, lymphoid hyperplasia, and persistent fetal hemoglobin                           |        1        |
# |                                                                 malonic aciduria                                                                 |        1        |
# |                                                mandibular hypoplasia-deafness-progeroid syndrome                                                 |        1        |
# |                                                             mandibuloacral dysplasia                                                             |        1        |
# |                                                          maternal riboflavin deficiency                                                          |        1        |
# |                                                   maturity-onset diabetes of the young type 3                                                    |        1        |
# |                                                   maturity-onset diabetes of the young type 2                                                    |        1        |
# |                                                   maturity-onset diabetes of the young type 14                                                   |        1        |
# |                                                   maturity-onset diabetes of the young type 13                                                   |        1        |
# |                                                   maturity-onset diabetes of the young type 11                                                   |        1        |
# |                                                   maturity-onset diabetes of the young type 10                                                   |        1        |
# |                                                   maturity-onset diabetes of the young type 1                                                    |        1        |
# |                                                       maturity-onset diabetes of the young                                                       |        1        |
# |                                                     maternally-inherited spastic paraplegia                                                      |        1        |
# |                                                    maternally-inherited diabetes and deafness                                                    |        1        |
# |                                                       maternally-inherited Leigh syndrome                                                        |        1        |
# |                                                             maternal phenylketonuria                                                             |        1        |
# |                                                   mandibuloacral dysplasia progeroid syndrome                                                    |        1        |
# |                                                                   mastocytosis                                                                   |        1        |
# |                                                                  mast syndrome                                                                   |        1        |
# |                                                     maple syrup urine disease, mild variant                                                      |        1        |
# |                                                         maple syrup urine disease type 2                                                         |        1        |
# |                                                        maple syrup urine disease type 1B                                                         |        1        |
# |                                                        maple syrup urine disease type 1A                                                         |        1        |
# |                                                            maple syrup urine disease                                                             |        1        |
# |                                                 mandibulofacial dysostosis-microcephaly syndrome                                                 |        1        |
# |                                                     mandibulofacial dysostosis with alopecia                                                     |        1        |
# |                                                mandibuloacral dysplasia with type B lipodystrophy                                                |        1        |
# |                                                mandibuloacral dysplasia with type A lipodystrophy                                                |        1        |
# |                                           macrocephaly, dysmorphic facies, and psychomotor retardation                                           |        1        |
# |                                          macrocephaly, acquired, with impaired intellectual development                                          |        1        |
# |                                                            lysosomal storage disease                                                             |        1        |
# |                                                               long QT syndrome 11                                                                |        1        |
# |                                              long chain 3-hydroxyacyl-CoA dehydrogenase deficiency                                               |        1        |
# |                                                                long QT syndrome 9                                                                |        1        |
# |                                                                long QT syndrome 6                                                                |        1        |
# |                                                                long QT syndrome 5                                                                |        1        |
# |                                                                long QT syndrome 3                                                                |        1        |
# |                                                                long QT syndrome 2                                                                |        1        |
# |                                                               long QT syndrome 16                                                                |        1        |
# |                                                               long QT syndrome 15                                                                |        1        |
# |                                                               long QT syndrome 14                                                                |        1        |
# |                                                               long QT syndrome 13                                                                |        1        |
# |                                                               long QT syndrome 12                                                                |        1        |
# |                                                               long QT syndrome 10                                                                |        1        |
# |                                                                long qt syndrome 8                                                                |        1        |
# |                                                                long QT syndrome 1                                                                |        1        |
# |                                                                 long QT syndrome                                                                 |        1        |
# |                                           localized junctional epidermolysis bullosa, non-Herlitz type                                           |        1        |
# |                                                         liver disease, severe congenital                                                         |        1        |
# |                                                     lissencephaly with cerebellar hypoplasia                                                     |        1        |
# |                                              lissencephaly type 1 due to doublecortin gene mutation                                              |        1        |
# |                                                         lissencephaly spectrum disorders                                                         |        1        |
# |                                       lissencephaly spectrum disorder with complex brainstem malformation                                        |        1        |
# |                                                       lissencephaly due to TUBA1A mutation                                                       |        1        |
# |                                                        lissencephaly due to LIS1 mutation                                                        |        1        |
# |                                               lissencephaly 9 with complex brainstem malformation                                                |        1        |
# |                                                   long chain acyl-CoA dehydrogenase deficiency                                                   |        1        |
# |                                                               loricrin keratoderma                                                               |        1        |
# |                                                      lysosomal acid phosphatase deficiency                                                       |        1        |
# |                                                             lymphatic malformation 4                                                             |        1        |
# |                                                         lysosomal acid lipase deficiency                                                         |        1        |
# |                                                          lysinuric protein intolerance                                                           |        1        |
# |                                                          lymphoproliferative syndrome 2                                                          |        1        |
# |                                                          lymphoproliferative syndrome 1                                                          |        1        |
# |                                                         lymphoma, non-Hodgkin, familial                                                          |        1        |
# |                                                  lymphedema-posterior choanal atresia syndrome                                                   |        1        |
# |                                                         lymphedema-distichiasis syndrome                                                         |        1        |
# |                                                             lymphatic malformation 9                                                             |        1        |
# |                                                             lymphatic malformation 8                                                             |        1        |
# |                                                             lymphatic malformation 7                                                             |        1        |
# |                                                             lymphatic malformation 6                                                             |        1        |
# |                                                             lymphatic malformation 3                                                             |        1        |
# |                                                    low phospholipid associated cholelithiasis                                                    |        1        |
# |                                                            lymphatic malformation 13                                                             |        1        |
# |                                                            lymphatic malformation 12                                                             |        1        |
# |                                                            lymphatic malformation 11                                                             |        1        |
# |                                                            lymphatic malformation 10                                                             |        1        |
# |                                                             lymphatic malformation 1                                                             |        1        |
# |                                                              lymphatic malformation                                                              |        1        |
# |                                                             lymphangioleiomyomatosis                                                             |        1        |
# |                                                          lung lymphangioleiomyomatosis                                                           |        1        |
# |                                                                   lung cancer                                                                    |        1        |
# ...
# |                                                                   cataract 38                                                                    |        1        |
# |                                                                   cataract 36                                                                    |        1        |
# |                                                                   cataract 33                                                                    |        1        |
# |                                                            cataract 31 multiple types                                                            |        1        |
# |                                                                   cataract 30                                                                    |        1        |
# |                                                            cataract 3 multiple types                                                             |        1        |
# |                                                                   cataract 23                                                                    |        1        |
# |                                                            cataract 22 multiple types                                                            |        1        |
# |                                                            cataract 21 multiple types                                                            |        1        |
# |                   cataract-growth hormone deficiency-sensory neuropathy-sensorineural hearing loss-skeletal dysplasia syndrome                   |        1        |
# |                                              cataract-intellectual disability-hypogonadism syndrome                                              |        1        |
# |                                              catecholaminergic polymorphic ventricular tachycardia                                               |        1        |
# |                                                                cerebellar ataxia                                                                 |        1        |
# |                                        cerebellar atrophy with seizures and variable developmental delay                                         |        1        |
# |                                                     cerebellar ataxia-hypogonadism syndrome                                                      |        1        |
# |                             cerebellar ataxia-areflexia-pes cavus-optic atrophy-sensorineural hearing loss syndrome                              |        1        |
# |                                         cerebellar ataxia, neuropathy, and vestibular areflexia syndrome                                         |        1        |
# |                                    cerebellar ataxia, intellectual disability, and dysequilibrium syndrome 4                                     |        1        |
# |                                    cerebellar ataxia, intellectual disability, and dysequilibrium syndrome 3                                     |        1        |
# |                                    cerebellar ataxia, intellectual disability, and dysequilibrium syndrome 2                                     |        1        |
# |                                    cerebellar ataxia, intellectual disability, and dysequilibrium syndrome 1                                     |        1        |
# |                                          cerebellar ataxia, intellectual disability, and dysequilibrium                                          |        1        |
# |                                      cerebellar ataxia, brain abnormalities, and cardiac conduction defects                                      |        1        |
# |                                  cerebellar ataxia with neuropathy and bilateral vestibular areflexia syndrome                                   |        1        |
# |                                                              centronuclear myopathy                                                              |        1        |
# |                                             catecholaminergic polymorphic ventricular tachycardia 1                                              |        1        |
# |                                    central hypoventilation syndrome, congenital, 2, and autonomic dysfunction                                    |        1        |
# |                              central hypoventilation syndrome, congenital, 1, with or without Hirschsprung disease                               |        1        |
# |                                                              central core myopathy                                                               |        1        |
# |                                                       central areolar choroidal dystrophy                                                        |        1        |
# |                                                           centra precocious puberty 1                                                            |        1        |
# |                                                                  caveolinopathy                                                                  |        1        |
# |                                                                caudal duplication                                                                |        1        |
# |                                             catecholaminergic polymorphic ventricular tachycardia 5                                              |        1        |
# |                                             catecholaminergic polymorphic ventricular tachycardia 4                                              |        1        |
# |                                             catecholaminergic polymorphic ventricular tachycardia 3                                              |        1        |
# |                                             catecholaminergic polymorphic ventricular tachycardia 2                                              |        1        |
# |                                                            cataract 20 multiple types                                                            |        1        |
# |                                                            cataract 2, multiple types                                                            |        1        |
# |                                                            cataract 19 multiple types                                                            |        1        |
# |                                                          cardiofaciocutaneous syndrome                                                           |        1        |
# |                                                           cardiomyopathy, dilated, 2G                                                            |        1        |
# |                                                           cardiomyopathy, dilated, 2F                                                            |        1        |
# |                                                           cardiomyopathy, dilated, 2E                                                            |        1        |
# |                                                           cardiomyopathy, dilated, 2D                                                            |        1        |
# |                                                           cardiomyopathy, dilated, 100                                                           |        1        |
# |                                                                  cardiomyopathy                                                                  |        1        |
# |                                                      cardiofacioneurodevelopmental syndrome                                                      |        1        |
# |                                                         cardiofaciocutaneous syndrome 4                                                          |        1        |
# |                                                         cardiofaciocutaneous syndrome 3                                                          |        1        |
# |                                                         cardiofaciocutaneous syndrome 2                                                          |        1        |
# |                                                         cardiofaciocutaneous syndrome 1                                                          |        1        |
# |                                cardioencephalomyopathy, fatal infantile, due to cytochrome c oxidase deficiency 4                                |        1        |
# |                                    cardiomyopathy, dilated, with wooly hair, keratoderma, and tooth agenesis                                     |        1        |
# |                                cardioencephalomyopathy, fatal infantile, due to cytochrome c oxidase deficiency 3                                |        1        |
# |                                cardioencephalomyopathy, fatal infantile, due to cytochrome c oxidase deficiency 2                                |        1        |
# |                                cardioencephalomyopathy, fatal infantile, due to cytochrome c oxidase deficiency 1                                |        1        |
# |                                                           cardioacrofacial dysplasia 2                                                           |        1        |
# |                                                           cardioacrofacial dysplasia 1                                                           |        1        |
# |                                                           cardiac-urogenital syndrome                                                            |        1        |
# |                                         cardiac, facial, and digital anomalies with developmental delay                                          |        1        |
# |                                                       cardiac valvular dysplasia, X-linked                                                       |        1        |
# |                                                           cardiac valvular dysplasia 2                                                           |        1        |
# |                                                      cardiac valvular defect, developmental                                                      |        1        |
# |                                   cardiac malformation, cleft lip/palate, microcephaly, and digital anomalies                                    |        1        |
# |                                                           cardiomyopathy, dilated, 2c                                                            |        1        |
# |                                                     cardiomyopathy, familial hypertrophic 27                                                     |        1        |
# |                                                                   cataract 18                                                                    |        1        |
# |                                                              carpal tunnel syndrome                                                              |        1        |
# |                                                            cataract 17 multiple types                                                            |        1        |
# |                                                            cataract 16 multiple types                                                            |        1        |
# |                                                            cataract 15 multiple types                                                            |        1        |
# |                                                            cataract 14 multiple types                                                            |        1        |
# |                                                        cataract 13 with adult I phenotype                                                        |        1        |
# |                                                            cataract 12 multiple types                                                            |        1        |
# |                                                            cataract 11 multiple types                                                            |        1        |
# |                                                            cataract 10 multiple types                                                            |        1        |
# |                                                            cataract 1 multiple types                                                             |        1        |
# |                                                         cataract - microcornea syndrome                                                          |        1        |
# |                                                            cartilage-hair hypoplasia                                                             |        1        |
# |                                                  carnitine-acylcarnitine translocase deficiency                                                  |        1        |
# |                                                    cardiomyopathy, familial hypertrophic, 28                                                     |        1        |
# |                                                   carnitine palmitoyltransferase II deficiency                                                   |        1        |
# |                                       carnitine palmitoyl transferase II deficiency, severe infantile form                                       |        1        |
# |                                           carnitine palmitoyl transferase II deficiency, neonatal form                                           |        1        |
# |                                          carnitine palmitoyl transferase II deficiency, myopathic form                                           |        1        |
# |                                                  carnitine palmitoyl transferase 1A deficiency                                                   |        1        |
# |                                                        cardiospondylocarpofacial syndrome                                                        |        1        |
# |                                                cardiomyopathy-hypotonia-lactic acidosis syndrome                                                 |        1        |
# |                                                     cardiomyopathy, familial restrictive, 6                                                      |        1        |
# |                                                     cardiomyopathy, familial restrictive, 3                                                      |        1        |
# |                                                     cardiomyopathy, familial restrictive, 1                                                      |        1        |
# |                                       cardiomyopathy, familial hypertrophic, 29, with polyglucosan bodies                                        |        1        |
# |                                                           zimmermann-laband syndrome 3                                                           |        1        |
# +--------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# <Axes: xlabel='Number of Genes', ylabel='Disease Name'>

# %%
# Step Three - Gene-Disease Confidence

'''When making decisions about gene disease relationships there are a complex set of criteria. The result is a categorical set of keywords that describe the confidence
of assertions. These are stored in the 'classification_title field of the original data'''

#pseudocode 9 - group the data by classification_title (confidence categories) and count the number of genes for each
'''###YOUR CODE HERE###'''

#pseudocode 10 - sort the data in descending order
'''###YOUR CODE HERE###'''

#pseudocode 11 - look at the first few rows of the dataframe
'''###YOUR CODE HERE###'''

#pseudocode 12 - create a table using the PrettyTable package
'''###YOUR CODE HERE###'''

#pseudocode 13 - plot the classification_titles with the most genes
'''###YOUR CODE HERE###'''

# %%
# Step Four - Modes of Inheritance

'''Many of these diseases are Mendelian diseases. This means that they are caused by a mutation in a single gene. These mutations are inherited in a particular way.
GenCC captures this information in the 'moi_curie' field'''

#pseudocode 14 - group the data by moi_curie (modes of inheritance) and count the number of genes for each
'''###YOUR CODE HERE###'''

'''This is good but the values we have here are accession ids that aren't very informative
We know that terms (classes) like 'HP:0000006' are actually from the Human Phenotype Ontology (HPO)
We're  going to use the BioPortal API to get infromation about these classes and then finish by merging these data with our table'''

# %%
'''first we need an API key from BioPortal. You can create an account on BioPortal for free and get an API key.
https://bioportal.bioontology.org/
For this example I will use my API key - note how I have it stored in a file in a separate folder and exclude this from the git repository'''

#load my API key for BioPortal
with open("../api_keys/bioportal.txt", "r") as file:
    apikey = file.read().strip()

'''Here is an example of how you can use the requests library to get information from the BioPortal API'''

#find details for an ontology term using the BioPortal API
import requests
import json

#set the URL for the BioPortal API - here we query with a fixed HP class id
url = 'http://data.bioontology.org/ontologies/HP/classes/HP:0000006?apikey='+apikey

#send the request
response = requests.get(url)

#parse the JSON in the response
class_info = response.json()

#display the JSON (for interest!)
print(json.dumps(class_info, indent=2))

#display the keys in the JSON (for interest!)
print(class_info.keys())

#display the values for the keys
print(class_info['@id'],class_info['prefLabel'])
print(class_info['definition'][0])

# %%
#pseudocode 15 - using the unique accession ids in the moi_curie field, get the names of the classes from the BioPortal API by modifying the code above
'''###YOUR CODE HERE###'''

#pseudocode 16 - merge the data with the moi_curie field with the data from the BioPortal API so now we have a dataframe that contains
# the mode of inheritance and the number of genes for each and the name of the mode of inheritance (don't put the definition in the table as it's too long)
'''###YOUR CODE HERE###'''

# %% [markdown]
# #### Well done!
# #### You've now practised FTP download, API use and also completed some data manipulation using Pandas, PrettyTable, and plotting with Seaborn
